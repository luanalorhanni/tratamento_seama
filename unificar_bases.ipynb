# %%
import pandas as pd
import os

# %%
#pastas = ['ACERTO_POR_HABILIDADE_2_A_9', 'HABILIDADE_DESEMPENHO_ESCOLA_2_A_9', 'HABILIDADE_DESEMPENHO_MUNICIPIO_1_A_9', 'HABILIDADE_DESEMPENHO_TURMA_1_A_9']
pastas = ['HABILIDADE_DESEMPENHO_TURMA_1_A_9']

# %%
for pasta in pastas:
    dfs = []

    for arquivo in os.listdir(pasta):
        caminho_arquivo = os.path.join(pasta, arquivo)

        try:
            if arquivo.endswith('.xlsx'):
                df = pd.read_excel(caminho_arquivo)
            elif arquivo.endswith('.csv'):
                df = pd.read_csv(caminho_arquivo, sep=';', engine='python')
            else:
                continue  # pula outros tipos de arquivo

            dfs.append(df)
        except Exception as e:
            print(f'Erro ao ler {arquivo} na pasta {pasta}: {e}')

    if dfs:
        df_unificado = pd.concat(dfs, ignore_index=True)
        nome_saida = f'{pasta}_unificado.xlsx'
        df_unificado.to_excel(nome_saida, index=False)
        print(f'✔ Arquivo salvo: {nome_saida}')
    else:
        print(f'⚠ Nenhum arquivo válido encontrado na pasta: {pasta}')
# Out:
# ✔ Arquivo salvo: HABILIDADE_DESEMPENHO_TURMA_1_A_9_unificado.xlsx

# %%
# Dicionário com os nomes a substituir
substituicoes_escola = {
    'ESCOLA MUNICIPAL DE TEMPO INTEGRAL NEGRO COSME': 'ESCOLA MUNICIPAL TEMPO INTEGRAL NEGRO COSME',
    'UEB ENS FUND PROF JOSE GONCALVES DO AMARAL RAPOSO': 'UEB PROF JOSE GONCALVES DO AMARAL RAPOSO',
    'UEB ENS FUND PROF MARIA THERESA CABRAL': 'UEB ENS FUND PROF MARIA THEREZA CABRAL'
}

substituicoes_ano = {
    'ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO': '2º ANO',
    'ENSINO FUNDAMENTAL DE 9 ANOS - 5º ANO': '5º ANO',
    'ENSINO FUNDAMENTAL DE 9 ANOS - 9º ANO': '9º ANO',
}

# %%
# Lista com os nomes dos arquivos a tratar
# arquivos = [
#     'HABILIDADE_DESEMPENHO_ESCOLA_2_A_9_unificado.xlsx',
#     'HABILIDADE_DESEMPENHO_TURMA_1_A_9_unificado.xlsx'
# ]
arquivos = [
    'HABILIDADE_DESEMPENHO_TURMA_1_A_9_unificado.xlsx'
]

for arquivo in arquivos:
    df = pd.read_excel(arquivo)

    # Aplica as substituições na coluna 'Escola'
    df['Escola'] = df['Escola'].replace(substituicoes_escola)
    
    # Aplica as substituições na coluna 'Escola'
    df['Ano Escolar'] = df['Ano Escolar'].replace(substituicoes_ano)

    # Salva com o mesmo nome (sobrescreve)
    df.to_excel(arquivo, index=False)
    print(f'✔ Nomes padronizados no arquivo: {arquivo}')
# Out:
# ✔ Nomes padronizados no arquivo: HABILIDADE_DESEMPENHO_TURMA_1_A_9_unificado.xlsx

# %%
arquivos_com_prefixos = {
    'HABILIDADE_DESEMPENHO_ESCOLA_2_A_9_unificado.xlsx': 'Escola_',
    'HABILIDADE_DESEMPENHO_MUNICIPIO_1_A_9_unificado.xlsx': 'Municipio_',
}

for arquivo, prefixo in arquivos_com_prefixos.items():
    print(f'\n📁 Atualizando colunas do arquivo: {arquivo}')
    
    df = pd.read_excel(arquivo)

    # Evita repetir o prefixo em colunas que já o tenham ou preservar colunas específicas
    novas_colunas = {
        col: f"{prefixo}{col}" for col in df.columns if not col.startswith(prefixo)
    }

    df.rename(columns=novas_colunas, inplace=True)

    # Salva sobrescrevendo o próprio arquivo
    df.to_excel(arquivo, index=False)

    print(f'✅ Colunas renomeadas com prefixo "{prefixo}".')
    print(f'🔍 Novos nomes de colunas: {list(df.columns)[:5]}...')
# Out:
# 📁 Atualizando colunas do arquivo: HABILIDADE_DESEMPENHO_ESCOLA_2_A_9_unificado.xlsx
# ✅ Colunas renomeadas com prefixo "Escola_".
# 🔍 Novos nomes de colunas: ['Escola_Avaliação', 'Escola_Rede', 'Escola_Ano Escolar', 'Escola_Componente Curricular', 'Escola_Estado']...
#
# 📁 Atualizando colunas do arquivo: HABILIDADE_DESEMPENHO_MUNICIPIO_1_A_9_unificado.xlsx
# ✅ Colunas renomeadas com prefixo "Municipio_".
# 🔍 Novos nomes de colunas: ['Municipio_Avaliação', 'Municipio_Rede', 'Municipio_Ano Escolar', 'Municipio_Componente Curricular', 'Municipio_Estado']...

# %%
inep = pd.read_excel("C:/Users/luana/Documents/SEMIT/SEMED/inep_escola.xlsx")

# %%
inep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_escola    262 non-null    int64
#  1   Escola       262 non-null    object
#  2   nucleo       262 non-null    object
#  3   INEP_ESCOLA  262 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.3+ KB

# %%
for arquivo in arquivos:
    df = pd.read_excel(arquivo)

    # Faz o merge com base na coluna 'Escola'
    df_merged = df.merge(inep, on='Escola', how='left')

    # Exibe visualizações
    print(f'\n📄 Visualização de {arquivo}')
    print(df_merged.head())

    print('\n🔢 Frequência dos códigos INEP encontrados:')
    print(df_merged['INEP_ESCOLA'].value_counts(dropna=False))

    # Salva o arquivo com os códigos INEP
    nome_saida = arquivo.replace('.xlsx', '_com_inep.xlsx')
    df_merged.to_excel(nome_saida, index=False)
    print(f'✅ Arquivo salvo: {nome_saida}')
# Out:
# 📄 Primeiras linhas de HABILIDADE_DESEMPENHO_ESCOLA_2_A_9_unificado.xlsx:
#                        Avaliação       Rede  \
# 0  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 1  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 2  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 3  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 4  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
#
#                              Ano Escolar  \
# 0  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO
# 1  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO
# 2  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO
# 3  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO
# 4  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO
#
#                    Componente Curricular    Estado  Regional Municipio  \
# 0  Língua Portuguesa - Escrita e Leitura  MARANHÃO  SAO LUIS  SAO LUIS
# 1  Língua Portuguesa - Escrita e Leitura  MARANHÃO  SAO LUIS  SAO LUIS
# 2  Língua Portuguesa - Escrita e Leitura  MARANHÃO  SAO LUIS  SAO LUIS
# 3  Língua Portuguesa - Escrita e Leitura  MARANHÃO  SAO LUIS  SAO LUIS
# 4  Língua Portuguesa - Escrita e Leitura  MARANHÃO  SAO LUIS  SAO LUIS
#
#                                         Escola  Previstos  Avaliados  ...  \
# 0  ESCOLA MUNICIPAL TEMPO INTEGRAL NEGRO COSME         24         23  ...
# 1                         UE DR AQUILES LISBOA         25         23  ...
# 2                     UEB ENS FUND 21 DE ABRIL         62         55  ...
# 3           UEB ENS FUND AGOSTINHO VASCONCELOS         43         39  ...
# 4                  UEB ENS FUND ALBERICO SILVA         48         44  ...
#
#    H 31 (%) H 32 (%) H 33 (%) H 34 (%) H 35 (%) H 36 (%) H 37 (%) id_escola  \
# 0       NaN      NaN      NaN      NaN      NaN      NaN      NaN    1247.0
# 1       NaN      NaN      NaN      NaN      NaN      NaN      NaN    1067.0
# 2       NaN      NaN      NaN      NaN      NaN      NaN      NaN    1155.0
# 3       NaN      NaN      NaN      NaN      NaN      NaN      NaN    1095.0
# 4       NaN      NaN      NaN      NaN      NaN      NaN      NaN    1009.0
#
#            nucleo INEP_ESCOLA
# 0          CENTRO           -
# 1  ITAQUI-BACANGA    21021945
# 2           RURAL    21272913
# 3            ANIL    21200807
# 4      COROADINHO    21016909
#
# [5 rows x 56 columns]
#
# 🔢 Quantidade de ocorrências por código INEP:
# INEP_ESCOLA
# -           28
# 21022119     7
# 21021686     7
# 21021511     7
# 21021945     7
#             ..
# 21016976     2
# 21020701     2
# 21225664     2
# 21016585     2
# 21016461     2
# Name: count, Length: 119, dtype: int64
# ✅ Atualizado: HABILIDADE_DESEMPENHO_ESCOLA_2_A_9_unificado.xlsx
#
# 📄 Primeiras linhas de HABILIDADE_DESEMPENHO_TURMA_1_A_9_unificado.xlsx:
#                        Avaliação       Rede  \
# 0  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 1  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 2  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 3  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
# 4  AVALIAÇÃO SOMATIVA SEAMA 2024  MUNICIPAL
#
#                              Ano Escolar Componente Curricular    Estado  \
# 0  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO                    LP  MARANHÃO
# 1  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO                    LP  MARANHÃO
# 2  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO                    LP  MARANHÃO
# 3  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO                    LP  MARANHÃO
# 4  ENSINO FUNDAMENTAL DE 9 ANOS - 2º ANO                    LP  MARANHÃO
#
#    Regional Municipio                                     Escola  \
# 0  SAO LUIS  SAO LUIS     UEB ENS FUND GOVERNADOR LEONEL BRIZOLA
# 1  SAO LUIS  SAO LUIS                  UEB ENS FUND JUSTO JANSEN
# 2  SAO LUIS  SAO LUIS  UEB ENS FUND HENRIQUE DE LA ROQUE ALMEIDA
# 3  SAO LUIS  SAO LUIS               UEB ENS FUND JOSEFINA SERRAO
# 4  SAO LUIS  SAO LUIS                     UEB ENS FUND PRIMAVERA
#
#        Código da Turma            Turma  ...  H 31 (%)  H 32 (%)  H 33 (%)  \
# 0  ㅤ19381231500001799ㅤ  2 A BRIZOLA-MAT  ...       NaN       NaN       NaN
# 1  ㅤ19381231500000889ㅤ          2 A MAT  ...       NaN       NaN       NaN
# 2  ㅤ19381231500001071ㅤ          2 A MAT  ...       NaN       NaN       NaN
# 3  ㅤ19381231500001092ㅤ          2 A MAT  ...       NaN       NaN       NaN
# 4  ㅤ19381231500001302ㅤ          2 A MAT  ...       NaN       NaN       NaN
#
#   H 34 (%) H 35 (%) H 36 (%) H 37 (%) id_escola          nucleo INEP_ESCOLA
# 0      NaN      NaN      NaN      NaN    1146.0   TURU-BEQUIMAO    21268967
# 1      NaN      NaN      NaN      NaN    1005.0          CENTRO    21016747
# 2      NaN      NaN      NaN      NaN    1038.0  ITAQUI-BACANGA    21020850
# 3      NaN      NaN      NaN      NaN    1039.0           RURAL    21020957
# 4      NaN      NaN      NaN      NaN    1062.0            ANIL    21021686
#
# [5 rows x 58 columns]
#
# 🔢 Quantidade de ocorrências por código INEP:
# INEP_ESCOLA
# -           76
# 21016348    52
# 21269203    45
# 21021368    44
# 21021783    43
#             ..
# 21022178     4
# 21016461     4
# 21022445     4
# 21225664     4
# 21021333     3
# Name: count, Length: 119, dtype: int64
# ✅ Atualizado: HABILIDADE_DESEMPENHO_TURMA_1_A_9_unificado.xlsx
